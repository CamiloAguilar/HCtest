# %%
import pandas as pd
import numpy as np

# %%
application_test = pd.read_csv("./application_test.csv")
application_train = pd.read_csv("./application_train.csv")

# %%
application_test.head(3)
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100001         Cash loans           F            N               Y
# 1      100005         Cash loans           M            N               Y
# 2      100013         Cash loans           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
# 1             0           99000.0    222768.0      17370.0         180000.0
# 2             0          202500.0    663264.0      69777.0         630000.0
#
#               ...             FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 0             ...                            0                0
# 1             ...                            0                0
# 2             ...                            0                0
#
#   FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# ...

# %%
application_train.groupby('NAME_TYPE_SUITE').count()
# Out:
#                  SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  \
# NAME_TYPE_SUITE
# Children               3267    3267                3267         3267
# Family                40149   40149               40149        40149
# Group of people         271     271                 271          271
# Other_A                 866     866                 866          866
# Other_B                1770    1770                1770         1770
# Spouse, partner       11370   11370               11370        11370
# Unaccompanied        248526  248526              248526       248526
#
#                  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# NAME_TYPE_SUITE
# Children                 3267             3267          3267
# Family                  40149            40149         40149
# Group of people           271              271           271
# Other_A                   866              866           866
# Other_B                  1770             1770          1770
# ...

# %%
application_train.head(3)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 0             ...                             0                0
# 1             ...                             0                0
# 2             ...                             0                0
#
#   FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0                0                0                        0.0
# ...

# %%
bureau = pd.read_csv("./bureau.csv")
bureau.head(3)
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# 1                     NaN                   0        225000.0
# 2                     NaN                   0        464323.5
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
# ...

# %%
bureau_balance = pd.read_csv("./bureau_balance.csv")
bureau_balance.head(3)
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C

# %%
bureau_balance.groupby("STATUS").count()
# Out:
#         SK_ID_BUREAU  MONTHS_BALANCE
# STATUS
# 0            7499507         7499507
# 1             242347          242347
# 2              23419           23419
# 3               8924            8924
# 4               5847            5847
# 5              62406           62406
# C           13646993        13646993
# X            5810482         5810482

# %%
credit_card_balance = pd.read_csv("./credit_card_balance.csv")
credit_card_balance.head(3)
# Out:
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 0     2562384      378907              -6       56.970
# 1     2582071      363914              -1    63975.555
# 2     1740877      371185              -7    31815.225
#
#    AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 0                   135000                       0.0                 877.5
# 1                    45000                    2250.0                2250.0
# 2                   450000                       0.0                   0.0
#
#    AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 0                         0.0                     877.5
# 1                         0.0                       0.0
# 2                         0.0                       0.0
#
#    AMT_INST_MIN_REGULARITY     ...      AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# 0                 1700.325     ...              0.000                 0.000
# ...

# %%
installments_payments = pd.read_csv("./installments_payments.csv")
installments_payments.head(3)
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0          -1180.0             -1187.0        6948.360     6948.360
# 1          -2156.0             -2156.0        1716.525     1716.525
# 2            -63.0               -63.0       25425.000    25425.000

# %%
POS_CASH_balance = pd.read_csv("./POS_CASH_balance.csv")
POS_CASH_balance.head(3)
# Out:
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0     1803195      182943             -31            48.0
# 1     1715348      367990             -33            36.0
# 2     1784872      397406             -32            12.0
#
#    CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                   45.0               Active       0           0
# 1                   35.0               Active       0           0
# 2                    9.0               Active       0           0

# %%
previous_application = pd.read_csv("./previous_application.csv")
previous_application.head(3)
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
#
#    HOUR_APPR_PROCESS_START            ...            NAME_SELLER_INDUSTRY  \
# 0                       15            ...                    Connectivity
# 1                       11            ...                             XNA
# 2                       11            ...                             XNA
#
# ...

# %%
sample_submission = pd.read_csv("./sample_submission.csv")
sample_submission.head(3)
# Out:
#    SK_ID_CURR  TARGET
# 0      100001     0.5
# 1      100005     0.5
# 2      100013     0.5

# %%
type_columns = x_test.columns.to_series().groupby(x_test.dtypes).groups
type_columns
# Out:
# {dtype('int64'): Index(['CNT_CHILDREN', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH',
#         'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE',
#         'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#         'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START',
#         'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#         'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#         'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2',
#         'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5',
#         'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8',
#         'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11',
#         'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14',
#         'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17',
#         'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#         'FLAG_DOCUMENT_21'],
#        dtype='object'),
# ...

# %%
type_columns = application_train.columns.to_series().groupby(application_train.dtypes).groups
type_columns
# Out:
# {dtype('int64'): Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#         'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#         'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#         'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START',
#         'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#         'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#         'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2',
#         'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5',
#         'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8',
#         'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11',
#         'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14',
#         'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17',
#         'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#         'FLAG_DOCUMENT_21'],
# ...

# %%
features = application_train.loc[[0]].drop("SK_ID_CURR",axis=1).drop("TARGET",axis=1).drop(
    "NAME_CONTRACT_TYPE",axis=1).drop("FLAG_OWN_CAR",axis=1).drop("FLAG_OWN_REALTY",axis=1).drop(
    "NAME_TYPE_SUITE",axis=1).drop("NAME_INCOME_TYPE",axis=1).drop("NAME_EDUCATION_TYPE",axis=1).drop("NAME_FAMILY_STATUS",axis=1).drop(
    "NAME_HOUSING_TYPE",axis=1).drop("OCCUPATION_TYPE",axis=1).drop("WEEKDAY_APPR_PROCESS_START",axis=1).drop("ORGANIZATION_TYPE",axis=1).drop(
    "FONDKAPREMONT_MODE",axis=1).drop("HOUSETYPE_MODE",axis=1).drop("WALLSMATERIAL_MODE",axis=1).drop("EMERGENCYSTATE_MODE",axis=1).columns
features
# Out:
# Index(['CODE_GENDER', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=105)

# %%
features = application_train.loc[[0]].drop("SK_ID_CURR",axis=1).drop("TARGET",axis=1).drop(
    "NAME_CONTRACT_TYPE",axis=1).drop("CODE_GENDER",axis=1).drop("FLAG_OWN_CAR",axis=1).drop("FLAG_OWN_REALTY",axis=1).drop(
    "NAME_TYPE_SUITE",axis=1).drop("NAME_INCOME_TYPE",axis=1).drop("NAME_EDUCATION_TYPE",axis=1).drop("NAME_FAMILY_STATUS",axis=1).drop(
    "NAME_HOUSING_TYPE",axis=1).drop("OCCUPATION_TYPE",axis=1).drop("WEEKDAY_APPR_PROCESS_START",axis=1).drop("ORGANIZATION_TYPE",axis=1).drop(
    "FONDKAPREMONT_MODE",axis=1).drop("HOUSETYPE_MODE",axis=1).drop("WALLSMATERIAL_MODE",axis=1).drop("EMERGENCYSTATE_MODE",axis=1).columns
features
# Out:
# Index(['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=104)

# %%
X = application_train[features]
y = application_train['TARGET']

# %%
prediction = application_test[features]

# %%
ID = application_test["SK_ID_CURR"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(X,y,test_size=0.3,random_state=31415)

# %%
print(X.shape, x_train.shape, x_test.shape)
# Out:
# (307511, 105) (215257, 105) (92254, 105)

# %%
nulos = x_train.apply(lambda x: x.isnull().sum(), axis=0)
nulos
# Out:
# CODE_GENDER                         0
# CNT_CHILDREN                        0
# AMT_INCOME_TOTAL                    0
# AMT_CREDIT                          0
# AMT_ANNUITY                         8
# AMT_GOODS_PRICE                   201
# REGION_POPULATION_RELATIVE          0
# DAYS_BIRTH                          0
# DAYS_EMPLOYED                       0
# DAYS_REGISTRATION                   0
# DAYS_ID_PUBLISH                     0
# OWN_CAR_AGE                    142177
# FLAG_MOBIL                          0
# FLAG_EMP_PHONE                      0
# FLAG_WORK_PHONE                     0
# FLAG_CONT_MOBILE                    0
# FLAG_PHONE                          0
# FLAG_EMAIL                          0
# CNT_FAM_MEMBERS                     2
# REGION_RATING_CLIENT                0
# REGION_RATING_CLIENT_W_CITY         0
# HOUR_APPR_PROCESS_START             0
# REG_REGION_NOT_LIVE_REGION          0
# REG_REGION_NOT_WORK_REGION          0
# LIVE_REGION_NOT_WORK_REGION         0
# ...

# %%
#x_train.apply(lambda x: x_train.x.fillna(x_train.x.mean(), inplace=True))

#x_train_ = x_train.apply(lambda x: x.fillna(x.mean(), inplace=True))
#x_train_.head(5)

#nulos_ = x_train.apply(lambda x: x.isnull().sum(), axis=0)
#nulos_

#x_train.AMT_GOODS_PRICE.fillna(x_train.AMT_GOODS_PRICE.median(), inplace=True)

#for column in x_train.columns:
#    print(column)

for column in x_train.columns:
    x_train[column].fillna(x_train[column].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     821         try:
# --> 822             x = float(x)
#     823         except Exception:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     824             try:
# --> 825                 x = complex(x)
#     826             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
for column in x_test.columns:
    x_test[column].fillna(x_test[column].mean(), inplace=True)

# %%
nulos = x_train.apply(lambda x: x.isnull().sum(), axis=0)
nulos
# Out:
# CNT_CHILDREN                   0
# AMT_INCOME_TOTAL               0
# AMT_CREDIT                     0
# AMT_ANNUITY                    0
# AMT_GOODS_PRICE                0
# REGION_POPULATION_RELATIVE     0
# DAYS_BIRTH                     0
# DAYS_EMPLOYED                  0
# DAYS_REGISTRATION              0
# DAYS_ID_PUBLISH                0
# OWN_CAR_AGE                    0
# FLAG_MOBIL                     0
# FLAG_EMP_PHONE                 0
# FLAG_WORK_PHONE                0
# FLAG_CONT_MOBILE               0
# FLAG_PHONE                     0
# FLAG_EMAIL                     0
# CNT_FAM_MEMBERS                0
# REGION_RATING_CLIENT           0
# REGION_RATING_CLIENT_W_CITY    0
# HOUR_APPR_PROCESS_START        0
# REG_REGION_NOT_LIVE_REGION     0
# REG_REGION_NOT_WORK_REGION     0
# LIVE_REGION_NOT_WORK_REGION    0
# REG_CITY_NOT_LIVE_CITY         0
# REG_CITY_NOT_WORK_CITY         0
# LIVE_CITY_NOT_WORK_CITY        0
# EXT_SOURCE_1                   0
# ...

# %%
nulos_test = x_test.apply(lambda x: x.isnull().sum(), axis=0)
nulos_test
# Out:
# CNT_CHILDREN                   0
# AMT_INCOME_TOTAL               0
# AMT_CREDIT                     0
# AMT_ANNUITY                    0
# AMT_GOODS_PRICE                0
# REGION_POPULATION_RELATIVE     0
# DAYS_BIRTH                     0
# DAYS_EMPLOYED                  0
# DAYS_REGISTRATION              0
# DAYS_ID_PUBLISH                0
# OWN_CAR_AGE                    0
# FLAG_MOBIL                     0
# FLAG_EMP_PHONE                 0
# FLAG_WORK_PHONE                0
# FLAG_CONT_MOBILE               0
# FLAG_PHONE                     0
# FLAG_EMAIL                     0
# CNT_FAM_MEMBERS                0
# REGION_RATING_CLIENT           0
# REGION_RATING_CLIENT_W_CITY    0
# HOUR_APPR_PROCESS_START        0
# REG_REGION_NOT_LIVE_REGION     0
# REG_REGION_NOT_WORK_REGION     0
# LIVE_REGION_NOT_WORK_REGION    0
# REG_CITY_NOT_LIVE_CITY         0
# REG_CITY_NOT_WORK_CITY         0
# LIVE_CITY_NOT_WORK_CITY        0
# EXT_SOURCE_1                   0
# ...

# %%
y.head(5)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int64

# %%
y.mean()
# Out:
# 0.08072881945686496

# %%
x_test.columns
# Out:
# Index(['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=104)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(ratio=0.5, random_state=31415)
X_res, y_res = sm.fit_sample(x_train, y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
print(X_res.shape, y_res.shape)
# Out:
# (296809, 104) (296809,)

# %%
y_res.mean()
# Out:
# 0.33333221027664256

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

models = {'lr': LogisticRegression(),
          'dt': DecisionTreeClassifier(),
          'rf': RandomForestClassifier(n_jobs=-1, random_state=31415),
          'gb': GradientBoostingClassifier(random_state=31415)}

# %%
for model in models.keys():
    models[model].fit(X_res, y_res)

# %%
y_pred = pd.DataFrame(index=x_test.index, columns=models.keys())
for model in models.keys():
    y_pred[model] = models[model].predict(x_test)

# %%
x_test.head(5)
# Out:
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 138254             0          180000.0   1200744.0      31806.0
# 228141             0          180000.0    622188.0      26284.5
# 155175             0          135000.0    156384.0      17815.5
# 69824              0          157500.0    254700.0      13068.0
# 176484             3          360000.0   1252674.0      84181.5
#
#         AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 138254        1048500.0                    0.019101      -14878
# 228141         472500.0                    0.018801      -18548
# 155175         135000.0                    0.046220      -11367
# 69824          225000.0                    0.019689      -16397
# 176484        1156500.0                    0.018029      -16677
#
#         DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  \
# 138254           -254            -3286.0            -4655
# 228141          -2782           -10972.0            -1682
# ...

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score, roc_auc_score

for model in models.keys():
    print(model,'accuracy',accuracy_score(y_test,y_pred[model]))
    print(model,'ROC',roc_auc_score(y_test,y_pred[model]))    
    print(model,'precision',precision_score(y_test,y_pred[model]))
    print(model,'recall',recall_score(y_test,y_pred[model]))
    print(model,'f1 score', f1_score(y_test,y_pred[model]))
# Out:
# lr accuracy 0.9116461074858543
# lr ROC 0.5087486096930104
# lr precision 0.18639575971731448
# lr recall 0.028356403709178874
# lr f1 score 0.04922430887670594
# dt accuracy 0.7024085676501832
# dt ROC 0.5346537753223974
# dt precision 0.09962789581082704
# dt recall 0.3346324418760919
# dt f1 score 0.1535425787753592
# rf accuracy 0.5400958224033646
# rf ROC 0.549728924254402
# rf precision 0.09635663028680864
# rf recall 0.5612148904717108
# rf f1 score 0.16447420244190625
# gb accuracy 0.8168859886834176
# gb ROC 0.5762561957674188
# gb precision 0.15649076900712314
# gb recall 0.2893428302647494
# gb f1 score 0.203122788810793

# %%
for column in x_test.columns:
    prediction[column].fillna(prediction[column].mean(), inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
Prob_lr = models['lr'].predict_proba(prediction)
Prob_dt = models['dt'].predict_proba(prediction)
Prob_rf = models['rf'].predict_proba(prediction)
Prob_gb = models['gb'].predict_proba(prediction)

# %%
dataf_lr = pd.DataFrame(Prob_lr)
dataf_dt = pd.DataFrame(Prob_dt)
dataf_rf = pd.DataFrame(Prob_rf)
dataf_gb = pd.DataFrame(Prob_gb)

# %%
df_lr = pd.DataFrame(ID)
df_lr["TARGET"] = dataf_lr[1]
df_lr = df_lr.set_index("SK_ID_CURR")
df_lr.to_csv("Probabilidad_lr.csv")

# %%
df_dt = pd.DataFrame(ID)
df_dt["TARGET"] = dataf_dt[1]
df_dt = df_dt.set_index("SK_ID_CURR")
df_dt.to_csv("Probabilidad_dt.csv")

# %%
df_rf = pd.DataFrame(ID)
df_rf["TARGET"] = dataf_rf[1]
df_rf = df_rf.set_index("SK_ID_CURR")
df_rf.to_csv("Probabilidad_rf.csv")

# %%
df_gb = pd.DataFrame(ID)
df_gb["TARGET"] = dataf_gb[1]
df_gb = df_gb.set_index("SK_ID_CURR")
df_gb.to_csv("Probabilidad_gb.csv")
